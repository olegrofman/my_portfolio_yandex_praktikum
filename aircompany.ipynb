# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Олег, привет!</b>
#
# Меня зовут Виталий Мехоношин, и я буду проверять твой проект. Предлагаю общаться на «ты» 😉
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Тобой проделана большая работа над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии. Так же есть несколько правил:<br>
# - <b>Пожалуйста, не перемещай, не изменяй и не удаляй комментарии.</b>
# - У комментариев могут быть приписки <b>V2, V3</b> и т.д., которые соответствуют версии проверки.
# - Еще обрати внимание на цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
# Комментарии такого цвета необходимо исправить, без их отработки проект не будет принят.
# </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
# На комментарии такого цвета нужно обязательно обратить внимание. Их не должно быть много.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
# Комментарии такого цвета будут содержать лайфхаки, которые смогут улучшить твой верный код, их необязательно исправлять.
# </div>
#
# Предлагаю работать над проектом в диалоге: если ты хочешь ответить на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии вот так:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# У тебя хорошая работа. Так же мне понравились твои рассуждения по всем пунктам проекта. Ты вполне корректно проверяешь выдвинутые гипотезы и хорошо разобрался в материале. Отдельный плюс за визуализацию и достаточно оптимальный подход к ней - в результате дополнительных пар строчек кода получается отличные, хорошо читаемые графики. Проект принят, удачи на следующих спринтах😊
#
# </div>

# %% [markdown]
# # Аналитика в авиакомпании
#
#
# **Цели и задачи проекта:** обработать небольшую выборку данных с информацией о деятельности авиакомпании в заданный период времени с целью анализа среднего количества рейсов в каждый город и задействованных моделей самолетов.
#
# **Входные данные:** два результата запросов из базы данных авиакомпании с информацией (1) о модели самолета
# и количестве рейсов для каждой модели в сентябре 2018 года и (2) о городах и среднем количестве рейсов, прибывающих в них за день в августе 2018 года.
#
# **Обозначения категорий исходных данных:**
# Исходные данные для проекта содержатся в двух файлах-запросах формата csv. Обозначения переменных для каждого датасета приведены ниже:
#
# 1) Информация о модели самолета и числе рейсов (query_1.csv)
# * *model* — модель самолета
# * *flights_amount* — количество рейсов для каждой модели самолетов model в сентябре 2018 года
#
# 2) Информация о городах и среднем количестве рейсов (query_3.csv)
# * *city* — город
# * *average_flights* — среднее количество рейсов, прибывающих в город за день в августе 2018 года
#
# **План работы** над проектом включает в себя выполнение следующих шагов:
# * *Импорт данных и изучение общей информации.* На этом этапе получаем общую информацию об имеющихся у нас в распоряжении данных, их типах, полноте и правильности представления. Предварительно оцениваем объем данных в каждом датасете, их минимальные и максимальные значения, присутствие пропусков и дубликатов.
# * *Подготовка данных.* В этой части работы обращаем пристальное внимание на недостатки исходных данных и их релевантность: анализируем пропуски (если присутствуют), оцениваем необходимость обработки пропусков в данных, преобразуем данные в верный тип, проверяем их на присутствие ошибочных значений и обрабатываем дубликаты (если присутствуют) с целью исключения искажений в результатах. Проверяем уникальность названий городов, куда летают самолеты авиакомпании.
#
# * *Анализ данных.* Данный этап позволяет охарактеризовать парк самолетов авиакомпании (модель, производитель) и наиболее популярные направления полетов внутри РФ в заданный период времени. Анализ данных также позволяет выделить, какие города являются транспортными хабами авиакомпании. Указанные зависимости отражаются в сводных таблицах и диаграммах, полученных по результатам группировки, подсчету и агрегирования различных данных.
#
# * *Формулирование общего вывода*. На заключительном этапе приводится сумма выводов и рекомендаций по каждой части выполненного проекта. В общем выводе мы отразим на основе имеющейся выборки ключевые особенности деятельности авиакомпании в запрашиваемые периоды времени.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Супер, что ты добавил такое подробное описание - это, действительно важно. Если человек взглянет на твой код, то сразу же будет в курсе того, что происходит. Так же хочется отметить что ты приводишь план действий над анализом - отлично.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Импорт-данных-и-информация-о-датасетах" data-toc-modified-id="Импорт-данных-и-информация-о-датасетах-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Импорт данных и информация о датасетах</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Среднее-число-рейсов-по-направлениям" data-toc-modified-id="Среднее-число-рейсов-по-направлениям-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Среднее число рейсов по направлениям</a></span></li><li><span><a href="#ТОП-10-городов-по-количеству-рейсов" data-toc-modified-id="ТОП-10-городов-по-количеству-рейсов-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>ТОП-10 городов по количеству рейсов</a></span></li><li><span><a href="#Количество-рейсов-по-модели-самолетов" data-toc-modified-id="Количество-рейсов-по-модели-самолетов-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Количество рейсов по модели самолетов</a></span></li><li><span><a href="#Количество-рейсов-по-производителю-самолетов" data-toc-modified-id="Количество-рейсов-по-производителю-самолетов-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Количество рейсов по производителю самолетов</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# ## Импорт данных и информация о датасетах

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_query1 = pd.read_csv('/datasets/query_1.csv')
df_query3 = pd.read_csv('/datasets/query_3.csv')

# %% [markdown]
# Предварительно ознакомимся с имеющимися датасетами, используя следующий шаблон:

# %%
def general_info(dataset):
    """
    Функция дает краткую информацию о датасете, максимальных и минимальных значениях численных переменных
    и присутствии дубликатов в данных
    """
    # Вывод всех колонок датасета из запроса
    print('')
    print('\033[1m' + 'Информация, включающая записи датасета:' + '\033[0m')
    pd.set_option('display.max_columns', None)
    display(dataset)
    
    # Вывод информации о размере датасета, типе данных и пропущенных/минимальных/максимальных значениях 
    print('\033[1m' + 'Информация о размере датасета, типе данных и пропущенных значениях:' + '\033[0m')
    dataset.info()
    print('')
    print('\033[1m' + 'Информация о минимальных/максимальных значениях для численных параметров:' + '\033[0m')
    display(dataset.describe().loc[['min','max']])
      
    # Вывод информации о количестве дубликатов
    duplicates_amount = dataset.duplicated().sum()
    print('\033[1m' + 'Количество дубликатов в данных:'+ '\033[0m', duplicates_amount)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Молодец, что оптимизируешь свой код. Такой шаблон очень универсален и подходит для многих проектов - супер. Мог бы рекомендоваить тебе в него добавить строку
#
# ```python
# pd.set_option('display.float_format', '{:,.2f}'.format)
# ```
# чтобы сократить кол-во запятых в `describe` и избавиться от экспонентациальных форм.
# </div>

# %% [markdown]
# Получим общую информацию о выборке из первого запроса о моделях самолетов и количестве рейсов с их использованием:

# %%
general_info(df_query1)
# Out:
# Информация, включающая записи датасета:
#                  model  flights_amount
# 0      Airbus A319-100             607
# 1      Airbus A321-200             960
# 2       Boeing 737-300             630
# 3       Boeing 767-300             600
# 4       Boeing 777-300             300
# 5   Bombardier CRJ-200            4446
# 6   Cessna 208 Caravan            4557
# 7  Sukhoi SuperJet-100            4185
# Информация о размере датасета, типе данных и пропущенных значениях:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# model             8 non-null object
# flights_amount    8 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes
#
# Информация о минимальных/максимальных значениях для численных параметров:
#      flights_amount
# min           300.0
# max          4557.0
# Количество дубликатов в данных: 0

# %% [markdown]
# **Промежуточные выводы**
# * Данные файла формата csv представлены в требуемой кодировке и не имеют нечитаемых символов;
# * Исходный датасет содержит 8 записей с информацией о моделях самолетов и общим количеством рейсов, выполненных на них в запрашиваемый период;
# * Параметры датасета представлены верным типом данных, не требующем преобразования;
# * Датасет не содержит пропуски и дубликаты;
# * Количественный параметр датасета (общее число перелетов в сентябре 2018 г.) находится в логически верном интервале минимальных и максимальных значений.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отлично, что приводишь такой подробный вывод для такого маленького датасета. С выводами согласен.
# </div>

# %% [markdown]
# Получим общую информацию о датасете из запроса о среднем числе рейсов по запрашиваемым направлениям:

# %%
general_info(df_query3)
# Out:
# Информация, включающая записи датасета:
#                city  average_flights
# 0            Абакан         3.870968
# 1           Анадырь         1.000000
# 2             Анапа         2.161290
# 3       Архангельск         5.354839
# 4         Астрахань         2.451613
# ..              ...              ...
# 96             Чита         1.580645
# 97           Элиста         4.870968
# 98   Южно-Сахалинск         4.290323
# 99           Якутск         2.741935
# 100       Ярославль         1.322581
#
# [101 rows x 2 columns]
# Информация о размере датасета, типе данных и пропущенных значениях:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
# city               101 non-null object
# average_flights    101 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB
#
# Информация о минимальных/максимальных значениях для численных параметров:
#      average_flights
# min         1.000000
# ...

# %% [markdown]
# **Промежуточные выводы**
# * Данные файла-запроса формата csv представлены в требуемой кодировке и не имеют нечитаемых символов;
# * Исходный датасет содержит 101 запись с информацией о городах-направлениях авиакомпании и среднем числе рейсов в каждый из них в запрашиваемый период;
# * Параметры датасета представлены верным типом данных, который не требует преобразования (среднее число рейсов будет округлено до следующего целого числа на более поздней стадии анализа, что позволит на начальном этапе провести лучшее ранжирование городов, но даст более логичное представление данных позднее);
# * Датасет не содержит пропуски и дубликаты;
# * Количественный параметр датасета (среднее число рейсов, прибывающих в город за день в августе 2018 года) находится в логически верном интервале минимальных и максимальных значений.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь ситуация аналогична выводами предыдущего датасета, молодец.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Проверим названия городов, формирующих датасет из запроса 3, на их уникальность:

# %%
len(df_query3['city'].unique())
# Out:
# 101

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# У `pandas` есть встроенная функция `nunique` - которая выведет сразу число, используй ее в будущем для таких случаев.
# </div>

# %% [markdown]
# Количество уникальных названий городов соответствует общему числу строк в датасете.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Лучше такую проверку делать программно, например:
#
# ```python
# df_query3['city'].nunique() == len(df_query3)
# ```
# и результатом будет `True` - это наглядно.
# </div>

# %% [markdown]
# Предварительно округлим значения среднего числа рейсов до первого знака после запятой:

# %%
df_query3['average_flights']=df_query3['average_flights'].round(1)

# %% [markdown]
# **Промежуточные выводы**
# * Количество уникальных названий городов соответствует общему числу строк в датасете.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Вывод корректен.
# </div>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Среднее число рейсов по направлениям

# %% [markdown]
# Проведем сортировку по среднему числу рейсов и представим города в порядке убывания. Дополнительно сформируем два датасета, включающих по 50 городов и ранжированных средних значений для удобства представления результатов на диаграмме:

# %%
df_query3 = df_query3.sort_values(by = 'average_flights', ascending = False)
df_query3_first50_cities = df_query3.head(50)
df_query3_last50_cities = df_query3.tail(51)

# %%
def annotation_graphs(graph, layout='h'):
    '''Функция добавляет аннотацию значений на графики в зависимости от горизонтальной (h) или вертикальной (v) ориентации
    столбцов барплота'''
    if layout == 'h':
        for p in graph.patches:
            graph.annotate(format(p.get_width(), '.1f'), 
                           (p.get_x() + p.get_width() + 3, p.get_y() + p.get_height()), 
                           ha = 'center', va = 'center', 
                           xytext = (0, 9), 
                           textcoords = 'offset points')
    else: 
        for p in g.patches:
            g.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize=(15, 15), sharex=True, constrained_layout=True)
fig.suptitle('Зависимость среднего числа рейсов, прибывающих в город за день в августе 2018 года')
g = sns.barplot(ax=axes[0], x='average_flights', y='city', data = df_query3_first50_cities, color = 'orange')
g.set_ylabel('Название города')
g.set_xlabel('Среднее число рейсов (ед.)')

annotation_graphs(g, 'h')

g = sns.barplot(ax=axes[1], x='average_flights', y='city', data = df_query3_last50_cities, color = 'orange')
g.set_ylabel('Название города')
g.set_xlabel('Среднее число рейсов (ед.)')

annotation_graphs(g, 'h')

plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Ты серьезно заморочился на создание красивой визуализации - супер. Так же не могу не отметить, что разделение на два графика здесь очень к месту, т.к. он получается очень большим. С точки зрения кода все хорошо.
# </div>

# %% [markdown]
# Городами-лидерами по числу прибывающих рейсов являются Москва, Санкт-Петербург, Новосибирск, Красноярск и Екатеринбург. Их лидерство обусловлено многими социально-экономическими причинами и туристической привлекательностью. Кроме того, важную роль начинают играть региональные транспортные хабы. Приоритетом авиакомпании являются промышленные города, ориентированные на нефтедобывающую и горно-металлургическую промышленность. Курортные города (за исключением Сочи) представлены небольшим числом рейсов. Также обращает на себя внимание большой охват по направлениям полетов авиакомпании.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Супер,что пользуешься внешними источниками информации, вывод очень подробный.
# </div>

# %% [markdown]
# Оценим частотное распределение среднего числа рейсов в запрашиваемый период:

# %%
plt.figure(figsize=(10, 6))

hist_avg_flights = df_query3['average_flights'].hist(bins = 15, range = (0, 20))
title = hist_avg_flights \
            .set_title('Гистограмма частот распределения средних значений рейсов (без учета Москвы и Санкт-Петербурга)')
x_lable = hist_avg_flights \
            .set_xlabel('Среднее число рейсов')
y_lable = hist_avg_flights \
            .set_ylabel('Частота')

plt.show()

# %% [markdown]
# Из гистограммы видно, что для частоты распределения рейсов (исключая Москву и Санкт-Петербург) характерно распределение близкое к бимодальному. Первый пик характеризует редкие рейсы (в т. ч. чартерные), но в большое число городов. Второй пик (меньшей интенсивности) связан с более частыми рейсами, но по ограниченным и наиболее востребованным направлениям.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами согласен.
# </div>

# %% [markdown]
# ### ТОП-10 городов по количеству рейсов

# %% [markdown]
# Определим 10 городов с наибольшим средним количеством рейсов, прибывающих в город за день в августе 2018 года:

# %%
cities_top10_flights = df_query3.sort_values(by = 'average_flights', ascending = False).head(10)
cities_top10_flights.index = cities_top10_flights.reset_index().index + 1 
display(cities_top10_flights)
# Out:
#                city  average_flights
# 1            Москва            129.8
# 2   Санкт-Петербург             31.2
# 3       Новосибирск             17.3
# 4        Красноярск             11.6
# 5      Екатеринбург             11.3
# 6    Ростов-на-Дону             10.2
# 7             Пермь             10.1
# 8            Брянск             10.0
# 9              Сочи              9.6
# 10        Ульяновск              9.6

# %% [markdown]
# Округлим до ближайшего целого числа среднее количество рейсов для ТОП-10 городов и представим результаты в виде диаграммы:

# %%
cities_top10_flights['average_flights'] = np.ceil(cities_top10_flights['average_flights']).astype('int')

# %%
plt.figure(figsize=(10, 6))

g = sns.barplot(x='average_flights', y='city', data = cities_top10_flights, color = 'orange')
g.set_title('Среднее число рейсов авиакомпании (округленное до большего значения) \
за день в августе 2018 года для ТОП-10 городов')
g.set_ylabel('Название города')
g.set_xlabel('Среднее число рейсов (ед.)')
sns.despine(left=False, bottom=False, right=True)
 
# Аннотация и вывод графика
annotation_graphs(g, 'h')
plt.text(100, 8, 'ТОП-10 городов', fontsize=15)
plt.show()

# %% [markdown]
# Достаточно интересным фактом является присутствие в списке ТОП-10 городов Ульяновска, по числу рейсов конкурирующего с Сочи. Возможно, это связано с тем, что город совмещает в себе развитый промышленный центр (авиастроение, машиностроение) и историческую/туристическую привлекательность. Следует, однако, учитывать, что авиакомпании помимо пассажирских перелетов выполняют значительное количество грузовых и чартерных рейсов, и в этой связи данные требуют дополнительного изучения, в т. ч. за более широкий временной период.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# По этому пункту так же все супер.
# </div>

# %% [markdown]
# ### Количество рейсов по модели самолетов

# %% [markdown]
# Общее число рейсов авиакомпании в указанный период составляет:

# %%
df_query1['flights_amount'].sum()
# Out:
# 16285

# %% [markdown]
# Оценим наиболее популярные модели самолетов, используемые авиакомпанией в заданный период:

# %%
df_query1 = df_query1.sort_values(by = 'flights_amount', ascending = False)

# %%
plt.figure(figsize=(10, 6))

g = sns.barplot(x='model', y='flights_amount', data = df_query1, color = 'c')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set_title('Зависимость количества рейсов авиакомпании от модели самолета в сентябре 2018 года')
g.set_ylabel('Количество рейсов (ед.)')
g.set_xlabel('Модель самолета')
sns.despine(left=True, bottom=False, right=True)

# Аннотация и вывод графика
annotation_graphs(g, 'v')
plt.show()

# %% [markdown]
# Флот авиакомпании представлен 8-ю моделями самолетов:
# * *Cessna 208 Caravan* (лёгкий одномоторный турбовинтовой самолёт с числом мест от 9 до 13 чел., используемый на авиалиниях малой протяжённости). Вероятнее всего, авиакомпания использует их в качестве бизнес-джетов;
# * *Bombardier CRJ-200* (региональный самолёт, основанный на бизнес-джете с пассажировместимостью до 50 чел.);
# * *Sukhoi SuperJet-100* (узкофюзеляжный пассажирский самолёт, предназначенный для перевозки от 87 до 108 пассажиров). Самолеты такого класса используются в ближнемагистральных и среднемагистральных перелетах;
# * *А320/319 и Boeing 737* - примеры дальне- и среднемагистральных узкофюзеляжных самолётов;
# * *Boeing 767 и 777* - широкофюзеляжные авиалайнеры, предназначенные для совершения полётов средней и большой протяжённости.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Визуализация отличная, молодец, что дал описание этим самолетом, т.к. именно эта информация позволяет корректно ответить на поставленные вопросы.
# </div>

# %% [markdown]
# Используя открытые источники, дополним имеющийся датасет *df_query1* данными по категориям самолетов и характерной максимальной дальности перелетов моделей. Выделим также производителя каждой модели:

# %%
df_query1['manufacturer']=df_query1['model'].str.split().str.get(0)
df_query1['type'] = pd.Series(['utility aircraft', 'regional jet' ,'narrow-body','narrow-body', \
                               'narrow-body','narrow-body', 'wide-body', 'wide-body'], index = df_query1.index)
df_query1['max_range_km'] = pd.Series(['1000', '3000' ,'4500','5900', \
                               '4100','6900', '7200', '11100'], index = df_query1.index)
df_query1.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_769cb0bc_c50e_11eb_ad06_02420a395fb2" ><thead>    <tr>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >flights_amount</th>        <th class="col_heading level0 col2" >manufacturer</th>        <th class="col_heading level0 col3" >type</th>        <th class="col_heading level0 col4" >max_range_km</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_769cb0bc_c50e_11eb_ad06_02420a395fb2row0_col0" class="data row0 col0" >Cessna 208 Caravan</td>
#                         <td id="T_769cb0bc_c50e_11eb_ad06_02420a395fb2row0_col1" class="data row0 col1" >4557</td>
#                         <td id="T_769cb0bc_c50e_11eb_ad06_02420a395fb2row0_col2" class="data row0 col2" >Cessna</td>
#                         <td id="T_769cb0bc_c50e_11eb_ad06_02420a395fb2row0_col3" class="data row0 col3" >utility aircraft</td>
# ...

# %% [markdown]
# Сгруппируем данные по классу самолета, чтобы оценить приоритетные направления авиакомпании по дальности перелетов:

# %%
flights_amount_for_model_type = df_query1.groupby('type')['flights_amount'].agg('sum').reset_index()
flights_amount_for_model_type['pct_flights_by_type'] = \
    (100 * flights_amount_for_model_type['flights_amount'] / flights_amount_for_model_type['flights_amount'].sum()).round(1)
flights_amount_for_model_type = flights_amount_for_model_type.sort_values(by='pct_flights_by_type', ascending = False)
flights_amount_for_model_type.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_76a2c128_c50e_11eb_ad06_02420a395fb2" ><thead>    <tr>        <th class="col_heading level0 col0" >type</th>        <th class="col_heading level0 col1" >flights_amount</th>        <th class="col_heading level0 col2" >pct_flights_by_type</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_76a2c128_c50e_11eb_ad06_02420a395fb2row0_col0" class="data row0 col0" >narrow-body</td>
#                         <td id="T_76a2c128_c50e_11eb_ad06_02420a395fb2row0_col1" class="data row0 col1" >6382</td>
#                         <td id="T_76a2c128_c50e_11eb_ad06_02420a395fb2row0_col2" class="data row0 col2" >39.2</td>
#             </tr>
#             <tr>
#                                 <td id="T_76a2c128_c50e_11eb_ad06_02420a395fb2row1_col0" class="data row1 col0" >utility aircraft</td>
#                         <td id="T_76a2c128_c50e_11eb_ad06_02420a395fb2row1_col1" class="data row1 col1" >4557</td>
# ...

# %% [markdown]
# Сводные данные по категориям самолетов указывают, что авиакомпания, в основном, ориентирована на использование самолетов для среднемагистральных рейсов (с большей вместимостью самолетов) и региональных рейсов (с меньшей вместимостью самолетов). Значительную долю (28%) в деятельности авиакомпании составляют перелеты на небольшие расстояния с наполняемостью самолета от 9 до 13 человек. Рейсы, ориентированные на максимальную протяженность, составляют не более 6% от общего числа перелетов в указанный период.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# С выводами по этому пункту согласен.
# </div>

# %% [markdown]
# ### Количество рейсов по производителю самолетов

# %% [markdown]
# Ниже приведен анализ по производителям самолетов, которые формируют флот авиакомпании:

# %%
df_query1_manufacturer_pivot = df_query1.pivot_table(index='manufacturer', values='flights_amount', aggfunc='sum') \
                                      .sort_values(by = 'flights_amount', ascending = False) \
                                      .reset_index()

# %%
plt.figure(figsize=(10, 6))

g = sns.barplot(x='manufacturer', y='flights_amount', data = df_query1_manufacturer_pivot, color = 'deepskyblue')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set_title('Количество рейсов авиакомпании на самолетах различных производителей в сентябре 2018 года')
g.set_ylabel('Количество рейсов (ед.)')
g.set_xlabel('Производитель самолета')
sns.despine(left=True, bottom=False, right=True)

# Аннотация и вывод графика
annotation_graphs(g, 'v')
plt.show()

# %% [markdown]
# Из графика видно, что авиапроизводители Cessna и Bombardier представлены в компании практически в равных пропорциях по количеству рейсов. Самолеты корпораций Airbus и Boeing также используются в равных пропорциях в авиакомпании, но с меньшей частотой. Рейсы с использованием самолетов корпорации-производителя Sukhoi используются чаще, чем самолеты Airbus или Boeing, а количество рейсов сопоставимо с нагрузкой на самолеты Bombardier. Это связано с межрегиональной направленностью деятельности компании, ориентированной на относительно частые перелеты средней протяженности, а также использование бизнес-джетов различной вместимости.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Да, действительно, именно первые 3 автопроизводителя существенно выделяются среди остальных.
# </div>

# %% [markdown]
# **Промежуточные выводы**
# * Авиакомпания предоставляет широкий охват по направлениям полетов.
# * Городами-лидерами по числу прибывающих рейсов являются: Москва, Санкт-Петербург, Новосибирск, Красноярск и Екатеринбург.
# * Приоритетными направлениями авиакомпании (за исключением Москвы и Санкт-Петербурга) являются промышленные города, в т. ч. ориентированные на нефтедобывающую и горно-металлургическую промышленность. Курортные города (за исключением Сочи) в деятельности авиакомпании в обозначенный период времени практически не представлены.
# * Важная роль авиакомпании заключается в формировании региональных транспортных хабов.
# * Авиакомпания имеет межрегиональную направленность, ориентированную на перелеты малой и средней протяженности, а также на использование бизнес-джетов различной вместимости.
# * Сводные данные по категориям самолетов указывают, что авиакомпания ориентируется на использование самолетов для среднемагистральных (39%) и региональных рейсов (27%).
# * Значительную долю (28%) в деятельности авиакомпании составляют чартерные перелеты на небольшие расстояния с наполняемостью самолета от 9 до 13 человек.
# * Рейсы, ориентированные на максимальную протяженность, составляют не более 6% от общего числа перелетов в указанный период.

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# * Деятельность авиакомпании представлена широкой сетью направлений полетов внутри страны.
# * Городами-лидерами в указанный период по прибывающим рейсам авиакомпании являются: Москва, Санкт-Петербург, Новосибирск, Красноярск и Екатеринбург.
# * Авиакомпания имеет межрегиональную направленность, ориентированную на перелеты малой и средней протяженности, а также на использование бизнес-джетов различной вместимости.
# * Флот авиакомпании включает 8 моделей самолетов, которые осуществляют перелеты как небольшой протяженности с небольшой вместимостью, так и на дальние расстояния с максимально возможной вместимостью.
# * Категории используемых самолетов указывают, что авиакомпания ориентируется на среднемагистральные (39%) и региональные рейсы (27%). Эти рейсы выполняются на самолетах Sukhoi SuperJet-100, Airbus A321/319, Boeing 737 и Bombardier CRJ-200.
# * Значительную долю (28%) в деятельности авиакомпании составляют чартерные перелеты на самолетах Cessna на небольшие расстояния с наполняемостью самолета от 9 до 13 человек. Эти рейсы выполняются самолетом марки Cessna 208 Caravan.
# * Рейсы, ориентированные на максимальную протяженность, составляют не более 6% от общего числа перелетов в указанный период. Они выполняются на самолетах Boeing 767-300 и Boeing 777-300.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Общие выводы очень подробные и чательные. Супер.
# </div>
